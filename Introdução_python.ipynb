# %% [markdown]
# <a href="https://colab.research.google.com/github/canradinha08/emanuela/blob/main/Introdu%C3%A7%C3%A3o_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("I competição de progrmação da Start|")

# %%
[ ] ano = "II"]

print(ano, "competição de programação da Start")

# %%
[ ] print(f"{ano} competição de programação da Start")
